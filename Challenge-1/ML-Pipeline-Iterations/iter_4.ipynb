# %% [markdown]
# # Iteration 4: Model Sweep and Tuning
#
# This notebook runs the `iter_4` workflow implemented in `iter_4_model_sweep.py`.
#
# It is intentionally based on the `iter_2` workflow and adds:
# - the locked `iter_2` logistic baseline
# - a baseline median CV accuracy benchmark
# - tuned decision tree, random forest, and gradient boosting sweeps
# - held-out audits for the baseline, strongest simple model, and strongest high-performance model

# %%
from pathlib import Path
import runpy

script_path = Path.cwd() / 'iter_4_model_sweep.py'
if not script_path.exists():
    raise FileNotFoundError(f'Could not find {script_path}')

namespace = runpy.run_path(str(script_path))
results = namespace['run_iter_4']()
# Out:
# Project root: C:\Users\GeorgeColinRamsay\Documents\Github\IS-455
# Challenge directory: C:\Users\GeorgeColinRamsay\Documents\Github\IS-455\Challenge-1
# Kaggle data directory: C:\Users\GeorgeColinRamsay\Documents\Github\IS-455\Challenge-1\data-Kaggle
# BartTorvik data directory: C:\Users\GeorgeColinRamsay\Documents\Github\IS-455\Challenge-1\data-BartTorvik
# Prepared table shapes:
# {
#   "team_features": [
#     1087,
#     485
#   ],
#   "matchup_rows": [
#     2140,
#     516
#   ],
#   "modeling_table": [
#     2140,
#     1598
#   ]
# }
# Selected sources:
#                        source_name                          filename prefix  rows  columns_added  coverage_pct
# 0                kenpom_barttorvik             KenPom Barttorvik.csv     kp  1147             95        100.00
# 1                     teamrankings                  TeamRankings.csv     tr  1147             38        100.00
# ...
